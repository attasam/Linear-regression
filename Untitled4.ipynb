# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\Attasam\Downloads\houserent.csv")

# %%
X_df = pd.DataFrame(data.Area)
y_df = pd.DataFrame(data.Price)


m = len(y_df)

# %%
plt.figure(figsize=(10,8))
plt.plot(X_df, y_df, 'kx')
plt.xlabel('Area in squre feet')
plt.ylabel('Price')
# Out:
# Text(0,0.5,'Price')

# %%
plt.figure(figsize=(10,8))
plt.plot(X_df, y_df, 'k.')
plt.plot([5, 22], [6,6], '-')
plt.plot([5, 22], [0,20], '-')
plt.plot([5, 15], [-5,25], '-')
plt.xlabel('Area in squre feet')
plt.ylabel('Price')
# Out:
# Text(0,0.5,'Price')

# %%
x_quad = [n/10 for n in range(0, 100)]
y_quad = [(n-4)**2+5 for n in x_quad]

# %%
plt.figure(figsize = (10,7))
plt.plot(x_quad, y_quad, 'k--')
plt.axis([0,10,0,30])
plt.plot([1, 2, 3], [14, 9, 6], 'ro')
plt.plot([5, 7, 8],[6, 14, 21], 'bo')
plt.plot(4, 5, 'ko')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Quadratic Equation')
# Out:
# Text(0.5,1,'Quadratic Equation')

# %%
iterations = 5
alpha = 0.0001

# %%
X = np.array(X_df)
y = np.array(y_df).flatten()
theta = np.random.rand(2,1)

# %%
def hypo(x,theta):
    h=theta[0]+x*theta[1]
    return h

# %%
def cost_function(X, y, theta):

    m = len(y) 
    f=hypo(X,theta)

    J = np.sum((f-y)**2)/1/m
    
    return J

# %%
cost_function(X, y, theta)
# Out:
# 12600134849881.652

# %%
def gradient_descent(X, y, theta, alpha, iterations):

    cost_history = [0] * iterations
    
    for iteration in range(iterations):
        hypothesis = hypo(X,theta)
        loss = hypothesis-y
        gradient = X.T.dot(loss)/m
        print( alpha*gradient)
        theta = theta - alpha*gradient
        cost = cost_function(X, y, theta)
        cost_history[iteration] = cost

    return theta, cost_history

# %%
(t, c) = gradient_descent(X,y,theta,alpha, iterations)
# Out:
# [[ -2995.63032239  -4195.63032239  -7495.63032239 -11995.63032239
#   -17995.63032239 -26995.63032239 -38995.63032239 -53995.63032239
#   -74995.63032239]]
# [[  29047.62869274   40683.62869274   72682.62869274  116317.62869274
#    174497.62869274  261767.62869274  378127.62869274  523577.62869274
#    727207.62869274]]
# [[ -281665.17289061  -394495.58622395  -704779.22289061 -1127893.27289061
#   -1692045.33955728 -2538273.43955728 -3666577.57289061 -5076957.73955728
#   -7051489.97289061]]
# [[  2731213.29312932   3825292.20108487   6834009.19796265
#    10936805.10279598  16407199.64257376  24612791.45224044
#    35553580.53179598  49229566.88124041  68375947.77046266]]
# [[ -2.64836649e+07  -3.70925834e+07  -6.62671092e+07  -1.06050553e+08
#    -1.59095146e+08  -2.38662034e+08  -3.44751219e+08  -4.77362700e+08
#    -6.63018774e+08]]

# %%
print (t)
# Out:
# [[  2.40080653e+07   3.36252993e+07   6.00726928e+07   9.61373202e+07
#     1.44223490e+08   2.16352745e+08   3.12525085e+08   4.32740510e+08
#     6.01042104e+08]
#  [  2.40080652e+07   3.36252992e+07   6.00726926e+07   9.61373201e+07
#     1.44223490e+08   2.16352745e+08   3.12525085e+08   4.32740509e+08
#     6.01042104e+08]]

# %%
print (np.array([3.5, 1]).dot(t))
print (np.array([7, 1]).dot(t))
# Out:
# [  1.08036294e+08   1.51313847e+08   2.70327117e+08   4.32617941e+08
#    6.49005705e+08   9.73587352e+08   1.40636288e+09   1.94733229e+09
#    2.70468947e+09]
# [  1.92064523e+08   2.69002394e+08   4.80581542e+08   7.69098562e+08
#    1.15378792e+09   1.73082196e+09   2.50020068e+09   3.46192408e+09
#    4.80833683e+09]

# %%
best_fit_x = np.linspace(0, 25, 20)
best_fit_y = [t[1] + t[0]*x for x in best_fit_x]

# %%
plt.figure(figsize=(10,6))
plt.plot(X_df, y_df, '.')
plt.plot(best_fit_x, best_fit_y, '-')
plt.axis([0,25,-5,25])
plt.xlabel('Area in squre feet')
plt.ylabel('Price')
plt.title('Price vs. Area with Linear Regression Line')
# Out:
# Text(0.5,1,'Price vs. Area with Linear Regression Line')
